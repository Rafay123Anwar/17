# %%
def wordpatterncheck(pattern,s):
    words=[]
    word=""
    # in this for loop i convert string to list
    for char in s :
        if char == " " : # this if condition  check if string contain gap or dash its append in words list
            words.append(word)
            word=""
        else : # this else append character in word varaible
            word += char
    words.append(word) # if any word left its append directly
    print(words)

    if len(pattern) != len(words) :  # thsi condtion check if length of pattern list and words list not same its return false
        return False

    # print(f"len of pattern : {len(pattern)} ")
    # print(f"len of words : {len(words)} ")

    # print("pattern")
    # for i in range(len(pattern)):
    #     print(pattern[i])

    # print("words")
    # for i in range(len(words)):
    #     print(words[i])


    # i create two for loops for check the both list
    for i in range(len(pattern)): # its iterate until the leght of pattern list
        for j in range(i+1,len(pattern)):
            if pattern[i]==pattern[j] and words[i] != words[j] : # thsi check if pattern in character i and character j is same  and pattern  and words in words i list  is not same
                print("this pattern[i]==pattern[j] call")
                return False
            if pattern[i] != pattern[j] and words[i] == words[j] : # thsi check if pattern in character i and character j is not same  and pattern  and words in words i list is same
                print("this pattern[i] != pattern[j] call")
                return False
    return True   # if in for loop both condition fail its return true


pattern="abcb"
s="dog fish cat fish"

print(wordpatterncheck(pattern,s))
# Out:
# ['dog', 'fish', 'cat', 'fish']
# True
